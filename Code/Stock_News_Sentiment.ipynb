# %% [markdown]
# <a href="https://colab.research.google.com/github/VIPinKumar07/Quantitative-Finance/blob/main/Code/Stock_News_Sentiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 📈**Introduction**
# In the dynamic world of finance, staying ahead of market trends is key to making informed decisions. One powerful way to gain insights into market sentiment is through sentiment analysis of news headlines. The Python code provided here is a robust tool designed to fetch and analyze recent news related to specific stock tickers, offering a glimpse into the sentiment surrounding companies like GS, JPM, MS, AAPL, NVDA, and GOOG.

# %% [markdown]
# ## Understanding the Code

# %% [markdown]
# The code utilizes various libraries, including Pandas, BeautifulSoup, and NLTK's VADER sentiment analyzer, to scrape financial news from the Finviz website. By fetching headlines and performing sentiment analysis, it provides a comprehensive overview of the market sentiment for the chosen stocks.

# %% [markdown]
# ## Python Code

# %%
# Importing necessary modules and libraries
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
from datetime import datetime

# %%
# Stocks to be Analysed- Goldman Sachs(GS), JP Morgan(MS), Morgan Stanley(MS), Apple(AAPL), Nvidia(NVDA),Google(GOOG)
num_news = 10
stocks = ['GS','JPM','MS','AAPL','NVDA','GOOG']

# Get news data from finviz website
url_finviz = 'https://finviz.com/quote.ashx?t='
news_tables = {}  # List to store stock news

# %%
for stock in stocks:
    url = url_finviz + stock
    request = Request(url=url, headers={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'})
    resp = urlopen(request)
    html = BeautifulSoup(resp, features="lxml")
    news_table = html.find(id='news-table')
    news_tables[stock] = news_table

# %%
# Display recent news headlines for each stock
try:
    for stock in stocks:
        df = news_tables[stock]
        df_tr = df.findAll('tr')

        print('\n')
        print('Recent news Headlines for {}: '.format(stock))
        print('----------------------------------')

        for i, table_row in enumerate(df_tr):
            news_text = table_row.a.text
            td_text = table_row.td.text.strip()
            print(news_text, '(', td_text,')')

            if i==num_news-1:
                break;
except KeyError:
    pass
# Out:
# Recent news Headlines for GS:
# ----------------------------------
# The Companies Conducting Layoffs in 2023: Heres the List ( Today 11:30AM )
# Goldman hopes to double private credit business as it retreats from consumer banking ( Dec-11-23 04:29PM )
# Final Trades: Cisco, Goldman Sachs and KLA Corp. ( 02:25PM )
# Goldman Sachs Group (GS) Rose on Successful Execution ( 04:29AM )
# The risk of recession is quite low, says Goldman Sachs' Jan Hatzius ( Dec-08-23 12:16PM )
# 2024 will be the year of bonds, says Goldman Sachs' Ashish Shah ( 09:10AM )
# Senator Warner: Big bank CEOs have an argument when it comes to the Feds proposed capital rules ( Dec-07-23 01:56PM )
# Sen. Warner 'frustrated' with banks ignoring liquidity risks ( 12:32PM )
# Big Banks Need More Out of Wall Street ( 11:28AM )
# How effective is Congress being in its banking regulations ( Dec-06-23 05:03PM )
#
#
# Recent news Headlines for JPM:
# ----------------------------------
# JPMorgan Winds Down Robo-Advisor, Cites Profitability Challenges ( Today 10:35AM )
# JPMorgan to outsource $500 billion custody business in Hong Kong, Taiwan - sources ( Dec-11-23 11:24PM )
# Investors itching to get out of cash: JPMorgan's Gabriela Santos ( 06:26PM )
# Overall retail complex is undervalued post-pandemic, says JPMorgan's Matthew Boss ( 03:26PM )
# The labor market is cooling off, says JPMorgan's Bob Michele ( 12:25PM )
# JPMorgan warns of 'catch-22 situation' for stocks next year ( 10:56AM )
# Ethiopia Bond Coupon Miss to Make It Africas Latest Default ( 10:45AM )
# JPMorgan (JPM) Struggles to Form Private Credit Syndicate ( 10:42AM )
# Exclusive-JPMorgan begins First Republic makeover as it opens more branches ( 10:04AM )
# Earnings Growth & Price Strength Make JPMorgan Chase & Co. (JPM) a Stock to Watch ( 09:30AM )
#
#
# Recent news Headlines for MS:
# ----------------------------------
# Morgan Stanley's Sherry Paul: Time to stop obsession over recession ( Dec-11-23 06:26PM )
# Morgan Stanley (MS) Surpasses Market Returns: Some Facts Worth Knowing ( 05:50PM )
# Hedge Fund and Insider Trading News: Ken Griffin, Steve Cohen, Paul Marshall, Warren Buffett, Fortress Investment Group, Black Stone Minerals LP (BSM), Best Buy Co., Inc. (BBY), and More ( 12:03PM )
# Top 15 Dividend Stocks To Buy According to Billionaires ( Dec-10-23 04:41PM )
# Apple's growth will accelerate incrementally each quarter, says Morgan Stanley's Erik Woodring ( Dec-08-23 05:12PM )
# Fed can't move toward cutting rates at current financial conditions: Morgan Stanley's Lisa Shalett ( 12:11PM )
# Morgan Stanley Is Pounding the Table on First Solar (FSLR) Stock ( 10:04AM )
# Investors Heavily Search Morgan Stanley (MS): Here is What You Need to Know ( 09:00AM )
# Morgan Stanley China A Share Fund, Inc. Announces Tender Offer ( Dec-07-23 04:00PM )
# Senator Warner: Big bank CEOs have an argument when it comes to the Feds proposed capital rules ( 01:56PM )
#
#
# Recent news Headlines for AAPL:
# ----------------------------------
# Google's court loss to Epic Games may cost billions but final outcome years away ( Today 01:28PM )
# First developer betas for iOS 17.3, iPadOS 17.3 out now ( 01:28PM )
# Apple Makes Security Changes to Protect Users From iPhone Thefts ( 01:25PM )
# Epic wins its antitrust lawsuit against the Play Store. What does this verdict mean for Google? ( 01:23PM )
# Stolen Device Protection to thwart iPhone & passcode thieves ( 01:22PM )
# Edgar Woolard, Who Brought Steve Jobs Back to Apple, Dies at Age 89 ( 12:50PM )
# Google, Epic Games fallout an 'unexpected outcome': Analyst ( 12:34PM )
# Apple's top U.S. App Store apps and games for 2023 ( 11:58AM )
# Best Dow Jones Stocks To Buy And Watch In December 2023: Apple At Buy Point ( 11:55AM )
# Apple to Support RCS, The Real  Why  Behind iMessage's U.S. Superiority, EU Leaning Against Regulating iMessage ( 11:37AM )
#
#
# Recent news Headlines for NVDA:
# ----------------------------------
# Is ServiceNow Stock a Top Buy for 2024? ( Today 11:38AM )
# Nvidia Is the S&P 500s Top Stock This Year. Why This Analyst Thinks It Also Will Be Hot in 2024. ( 11:33AM )
# If You Invested $1,000 in Advanced Micro Devices in 2015, This Is How Much You Would Have Today ( 11:17AM )
# Nvidia stock rises after US commerce secretary's comments ( 11:07AM )
# Nvidia: 1 Unlikely Reason Why This Artificial Intelligence (AI) Stock Could Skyrocket in 2024 ( 09:59AM )
# Nvidia Stock Isn't Losing Its AI Crown Anytime Soon. Buy NVDA Now. ( 09:23AM )
# The Average Retirement Savings for American Households Is Just $87,000. These 3 Stocks Could Help You Beat That. ( 08:15AM )
# Second Annual M100 Awards Reflect Commitments to Innovation and Advancements ( 08:00AM )
# 11 Best Jim Cramer Stocks To Buy According to Billionaires ( 07:46AM )
# NVIDIA (NVDA) Taps Southeast Asia Amid China Sales Restriction ( 07:11AM )
#
#
# Recent news Headlines for GOOG:
# ----------------------------------
# Epic Games wins antitrust lawsuit against Google: What you need to know ( Today 01:30PM )
# Google's court loss to Epic Games may cost billions but final outcome years away ( 01:28PM )
# Epic wins its antitrust lawsuit against the Play Store. What does this verdict mean for Google? ( 01:23PM )
# Alphabet Is Dropping Some Letters on the Charts ( 01:22PM )
# These Stocks Are Moving the Most Today: Oracle, Incyte, Lucid, Blue Bird, Hasbro, Johnson Controls, Centene, and More ( 12:57PM )
# Google, Epic Games fallout an 'unexpected outcome': Analyst ( 12:34PM )
# The Epic Games antitrust win against Google paves the way for a bigger app store upset ( 11:51AM )
# 10 A-Rated Stocks Billionaires Are Loading Up On ( 11:22AM )
# Why Google's Antitrust Case Loss Against 'Fortnite' Maker Epic Games Matters for Big Tech ( 11:06AM )
# What Google's antitrust loss to Epic Games means for tech ( 10:22AM )

# %%
# Extract and parse news data
parsed_news = []
for stock in stocks:
    news_table =news_tables[stock]
    df_tr = news_table.findAll('tr')

    for i,row in enumerate(df_tr):
        text = row.a.text
        date_scrape = row.td.text.split()

        if len(date_scrape) == 1:
            time = date_scrape[0]
            date = 'Today'
        else:
            date = date_scrape[0]
            time = date_scrape[1]

        stock_name = stock.split('_')[0]
        parsed_news.append([stock_name, date, time, text])

# %%
# Create dataframe of news headlines with sentiment scores
columns = ['Stock', 'Date', 'Time', 'Headline']
news = pd.DataFrame(parsed_news, columns=columns)
print(news.shape)
news.head(10)
# Out:
# (600, 4)
#   Stock       Date     Time                                           Headline
# 0    GS      Today  11:30AM  The Companies Conducting Layoffs in 2023: Here...
# 1    GS  Dec-11-23  04:29PM  Goldman hopes to double private credit busines...
# 2    GS      Today  02:25PM   Final Trades: Cisco, Goldman Sachs and KLA Corp.
# 3    GS      Today  04:29AM  Goldman Sachs Group (GS) Rose on Successful Ex...
# 4    GS  Dec-08-23  12:16PM  The risk of recession is quite low, says Goldm...
# 5    GS      Today  09:10AM  2024 will be the year of bonds, says Goldman S...
# 6    GS  Dec-07-23  01:56PM  Senator Warner: Big bank CEOs have an argument...
# 7    GS      Today  12:32PM  Sen. Warner 'frustrated' with banks ignoring l...
# 8    GS      Today  11:28AM             Big Banks Need More Out of Wall Street
# 9    GS  Dec-06-23  05:03PM  How effective is Congress being in its banking...

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Perform sentiment analysis
analyzer = SentimentIntensityAnalyzer()

scores = news['Headline'].apply(analyzer.polarity_scores).tolist()
scores_df = pd.DataFrame(scores)

# Join sentiment scores to news dataframe
news = news.join(scores_df)
news.head()
# Out:
#   Stock       Date     Time  \
# 0    GS      Today  11:30AM
# 1    GS  Dec-11-23  04:29PM
# 2    GS      Today  02:25PM
# 3    GS      Today  04:29AM
# 4    GS  Dec-08-23  12:16PM
#
#                                             Headline    neg    neu    pos  \
# 0  The Companies Conducting Layoffs in 2023: Here...  0.000  1.000  0.000
# 1  Goldman hopes to double private credit busines...  0.000  0.671  0.329
# 2   Final Trades: Cisco, Goldman Sachs and KLA Corp.  0.000  1.000  0.000
# 3  Goldman Sachs Group (GS) Rose on Successful Ex...  0.000  0.648  0.352
# 4  The risk of recession is quite low, says Goldm...  0.448  0.552  0.000
#
#    compound
# 0    0.0000
# 1    0.6597
# 2    0.0000
# 3    0.5859
# 4   -0.7425

# %%
# Convert date to datetime object
news['Date'] = news['Date'].apply(lambda x: datetime.now().date() if x == 'Today' else x)  # Substitute "Today" with current date
news['Date'] = pd.to_datetime(news['Date'])
#news = news.drop(columns=['Headline'])

# Group news by ticker and calculate mean sentiment for each
unique_stocks = news['Stock'].unique().tolist()
mean_sentiments = []
for stock in stocks:
    dataframe = news[news['Stock'] == stock]
    mean = round(dataframe['compound'].mean(), 2)
    mean_sentiments.append(mean)

# Create and display dataframe of tickers with mean sentiment scores
sentiments_df = pd.DataFrame(list(zip(stocks, mean_sentiments)), columns=['Stock', 'Mean Sentiment'])
sentiments_df = sentiments_df.set_index('Stock')
sentiments_df = sentiments_df.sort_values('Mean Sentiment', ascending=False)
print('\n')
sentiments_df.head()
# Out:
#        Mean Sentiment
# Stock
# NVDA             0.26
# MS               0.12
# GS               0.10
# JPM              0.10
# GOOG             0.10
